# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [4]</a>'.</span>

# %%
#@title Cell 1: Setup Environment ⚙️
from pathlib import Path
import os, sys
import subprocess

# Detect current platform
def detect_current_platform():
    """Detect the current cloud GPU platform"""
    if os.path.exists('/content'):
        return 'colab'
    elif os.path.exists('/kaggle'):
        return 'kaggle'
    elif os.path.exists('/workspace'):
        return 'workspace'
    elif 'LIGHTNING_CLOUD_PROJECT_ID' in os.environ:
        return 'lightning'
    elif 'PAPERSPACE_GRADIENT_ID' in os.environ:
        return 'paperspace'
    elif 'RUNPOD_POD_ID' in os.environ:
        return 'runpod'
    elif 'VAST_CONTAINERLABEL' in os.environ:
        return 'vast'
    elif 'SAGEMAKER_INTERNAL_IMAGE_URI' in os.environ:
        return 'sagemaker'
    else:
        return 'local'

def get_platform_root():
    """Get the appropriate root directory for the platform"""
    platform = detect_current_platform()
    if platform == 'colab':
        return Path('/content')
    elif platform == 'kaggle':
        return Path('/kaggle/working')
    elif platform == 'workspace':
        return Path('/workspace')
    elif platform == 'lightning':
        return Path.home() / 'work'
    elif platform == 'paperspace':
        return Path('/notebooks')
    elif platform == 'runpod':
        return Path('/workspace')
    elif platform == 'vast':
        return Path('/workspace')
    elif platform == 'sagemaker':
        return Path('/opt/ml/code')
    else:
        return Path.home()

# Hybrid dual-framework bootstrap with Dark Mode Pro theming
platform_detected = detect_current_platform()
project_root = get_platform_root() / 'SD-DarkMaster-Pro'
scripts_dir = project_root / 'scripts'

# Self-cloning bootstrap sequence
if not project_root.exists():
    print(f"🚀 Initializing SD-DarkMaster-Pro on {platform_detected} platform...")
    print(f"📁 Project root: {project_root}")
    
    # Clone the repository
    repo_url = "https://github.com/anxietysolo/SD-DarkMaster-Pro.git"
    subprocess.run(['git', 'clone', repo_url, str(project_root)], check=True)
    print("✅ Repository cloned successfully!")
else:
    print(f"✅ SD-DarkMaster-Pro already exists at {project_root}")
    
# Add project to path
sys.path.insert(0, str(project_root))

# Run setup script with platform-specific optimizations
setup_script = scripts_dir / 'setup.py'
if setup_script.exists():
    print(f"🔧 Running setup for {platform_detected} platform with Dark Mode Pro theme...")
    exec(open(setup_script).read())
else:
    print("⚠️ Setup script not found. Please ensure the repository is properly cloned.")
# Out:
# ✅ SD-DarkMaster-Pro already exists at /workspace/SD-DarkMaster-Pro
# 🔧 Running setup for workspace platform with Dark Mode Pro theme...
# 2025-08-20 02:29:15,934 | INFO | Loaded 29 extensions for pre-installation
#
# ============================================================
# 🌟 SD-DarkMaster-Pro Setup v1.0.0
# 🎨 Dark Mode Pro Theme Activated
# 🖥️  Platform: workspace
# 🚀 GPU Available: False
# ============================================================
#
# 2025-08-20 02:29:15,936 | INFO | Session initialized: f8c8b33b
# 2025-08-20 02:29:15,936 | INFO | Installing core dependencies...
# 2025-08-20 02:29:15,937 | INFO | Installing 23 dependencies for workspace
# 2025-08-20 02:29:16,978 | INFO | Installed batch 1: ['streamlit>=1.28.0', 'gradio>=4.0.0', 'torch>=2.0.0', 'torchvision', 'transformers>=4.30.0']
# 2025-08-20 02:29:17,442 | INFO | Installed batch 2: ['diffusers>=0.21.0', 'accelerate', 'xformers', 'opencv-python', 'Pillow>=10.0.0']
# 2025-08-20 02:29:17,888 | INFO | Installed batch 3: ['numpy', 'pandas', 'requests', 'tqdm', 'pyyaml']
# 2025-08-20 02:29:18,345 | INFO | Installed batch 4: ['jsonschema', 'aiohttp', 'aiofiles', 'psutil', 'matplotlib']
# 2025-08-20 02:29:18,801 | INFO | Installed batch 5: ['seaborn', 'plotly', 'rich']
# 2025-08-20 02:29:18,801 | INFO | Setting up unified storage...
# 2025-08-20 02:29:18,802 | INFO | Setting up unified storage structure...
# 2025-08-20 02:29:18,802 | INFO | Created checkpoints directory: /workspace/SD-DarkMaster-Pro/storage/models/Stable-diffusion
# 2025-08-20 02:29:18,803 | INFO | Created vae directory: /workspace/SD-DarkMaster-Pro/storage/models/VAE
# 2025-08-20 02:29:18,803 | INFO | Created lora directory: /workspace/SD-DarkMaster-Pro/storage/models/Lora
# 2025-08-20 02:29:18,804 | INFO | Created embeddings directory: /workspace/SD-DarkMaster-Pro/storage/embeddings
# 2025-08-20 02:29:18,804 | INFO | Created hypernetworks directory: /workspace/SD-DarkMaster-Pro/storage/models/hypernetworks
# 2025-08-20 02:29:18,805 | INFO | Created controlnet directory: /workspace/SD-DarkMaster-Pro/storage/models/ControlNet
# 2025-08-20 02:29:18,805 | INFO | Created upscalers directory: /workspace/SD-DarkMaster-Pro/storage/models/ESRGAN
# 2025-08-20 02:29:18,806 | INFO | Creating configuration files...
# 2025-08-20 02:29:18,807 | INFO | Created Streamlit config: /workspace/SD-DarkMaster-Pro/configs/streamlit/config.toml
# 2025-08-20 02:29:18,807 | INFO | Created Gradio config: /workspace/SD-DarkMaster-Pro/configs/gradio_fallback/interface_config.json
# 2025-08-20 02:29:18,808 | INFO | Created environment config: /workspace/SD-DarkMaster-Pro/configs/environment.json
#
# ============================================================
# ✅ Setup Complete!
# ⏱️  Duration: 2.88 seconds
# 📁 Project Root: /workspace/SD-DarkMaster-Pro
# 🎨 Theme: Dark Mode Pro
# 🚀 Status: Ready to launch
# ============================================================
# <string>:656: RuntimeWarning: coroutine 'SetupOrchestrator.run_setup' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
#@title Cell 2: Hybrid Dashboard & CivitAI Browser 🌟
# This cell launches the hybrid Streamlit/Gradio interface with native CivitAI browser
# %run $scripts_dir/widgets-en.py
# Out:
# 2025-08-20 02:29:23.436 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.437 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ============================================================
# 🌟 SD-DarkMaster-Pro Hybrid Dashboard
# 🎨 Dark Mode Pro Theme Activated
# ============================================================
# 2025-08-20 02:29:23.469
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /workspace/SD-DarkMaster-Pro/scripts/widgets-en.py [ARGUMENTS]
# 2025-08-20 02:29:23.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.480 Session state does not function when running a script without `streamlit run`
# 2025-08-20 02:29:23.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:26.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 02:29:27.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#@title Cell 3: Intelligent Downloads & Storage 📦
# This cell handles all downloads with unified storage management
# %run $scripts_dir/downloading-en.py

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
#@title Cell 4: Multi-Platform WebUI Launch 🚀
# This cell launches the selected WebUI with platform-specific optimizations
# %run $scripts_dir/launch.py

# %%
#@title Cell 5: Advanced Storage Management 🧹
# This cell provides storage visualization and cleanup tools
# %run $scripts_dir/auto-cleaner.py
